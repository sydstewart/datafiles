# %% [markdown]
# <a href="https://colab.research.google.com/github/sydstewart/datafiles/blob/master/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade -q gspread
from google.colab import auth
auth.authenticate_user()

import gspread
from oauth2client.client import GoogleCredentials

gc = gspread.authorize(GoogleCredentials.get_application_default())
# Open our new sheet and read some data.
worksheet = gc.open('GoogleCharts').sheet1

# get_all_values gives a list of rows.
rows = worksheet.get_all_values()
#print(rows)

# Convert to a DataFrame and render.
import pandas as pd
input = pd.DataFrame.from_records(rows)

print(input)
# input = pd.DataFrame.from_records(rows)

col_name1 =input.columns[0]
col_name2 =input.columns[1]
col_name3 =input.columns[2]
col_name4 =input.columns[3]
col_name5 =input.columns[4]
col_name6 =input.columns[5]
col_name7 =input.columns[6]
input=input.rename(columns = {col_name1:'Show'})
input=input.rename(columns = {col_name2:'Filename'})
input=input.rename(columns = {col_name3:'Datecol'})
input=input.rename(columns = {col_name4:'Namecol'})
input=input.rename(columns = {col_name5:'Title'})
input=input.rename(columns = {col_name6:'Folder'})
input=input.rename(columns = {col_name7:'NoteCol'})

input = input[input.Show == 'y']

dc = input
print (dc)

#count rows in dataframe
dctotal_rows = dc['Datecol'].count()
#print ('Rows=',dctotal_rows)

#Produce chart for each entry in dc set to 'y'
        
for i in range(0,dctotal_rows):
        filename= dc['Filename'].iloc[i]
        pointdate = dc[ 'Datecol'].iloc[i]
        pointname = dc['Namecol'].iloc[i]
        dctitle = dc['Title'].iloc[i]
        dcfolder = dc['Folder'].iloc[i]
        dcannot = dc['NoteCol'].iloc[i]
        print()
        print ('-------------------------------------------')
        print  (dc['Title'].iloc[i])
        print ('-------------------------------------------')
        print()
        #Read in data

        dateparse= lambda x: pd.datetime.strptime(x, '%d/%m/%Y')
#        df = pd.read_csv( filename, parse_dates=[pointdate], date_parser= dateparse)
# Out:
#        0                                   1               2         3  \
# 0   Show                            Filename          Folder   Datecol
# 1      n                        SalesNos.csv            Test  SaleDate
# 2      n                        SalesNos.csv  Implementation  SaleDate
# 3      n                        SalesNos.csv  Implementation  SaleDate
# 4      n                    Sales Trend2.csv            Test  SaleDate
# 5      n                    Sales Trend2.csv            Test  SaleDate
# 6      n                  CasesRangeTest.csv   Support Cases  WeekDate
# 7      n                           Cases.csv   Support Cases  WeekDate
# 8      n                           Cases.csv   Support Cases  WeekDate
# 9      n                           Cases.csv   Support Cases  WeekDate
# 10     n                           Cases.csv   Support Cases  WeekDate
# 11     n                           Cases.csv   Support Cases  WeekDate
# ...
